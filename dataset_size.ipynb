# %%
import json
from operator import index
import os
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import pickle
import time

# %%
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.neural_network import MLPRegressor
from sklearn.ensemble import ExtraTreesRegressor
import xgboost as xgb
#import tensorflow as tf

from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler, RobustScaler

from sklearn.model_selection import train_test_split, cross_validate, ShuffleSplit

from sklearn.metrics import mean_absolute_percentage_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
from sklearn.metrics import median_absolute_error

import warnings
warnings.filterwarnings('once', '.*sliced data.*', )
warnings.filterwarnings('once', '.*Maximum iterations*', )
# Out:
# /home/max/.local/lib/python3.8/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index

# %%
def prepare_dataset(path : str, workload_name : str):
    dataset = {}
    files = os.listdir(path)

    for file in files:
        with open(path+"/"+file, "r") as f:
            raw_str = f.read()
        data = json.loads(raw_str)

        if "layers" in data.keys():
            del data["layers"]

        if "relay" in data.keys():
            del data["relay"]

        if "conv2d" in workload_name:
            data["kernel_0"] = data["kernel"][0]
            data["kernel_1"] = data["kernel"][1]
            del data["kernel"]
            data["dilation_0"] = data["dilation"][0]
            data["dilation_1"] = data["dilation"][1]
            del data["dilation"]

            if not "kernel layout" in data.keys():
                data["kernel layout"] = "OIHW"

        elif workload_name == "dense":
            data["features"] = data["input shape"][1]
            del data["input shape"]
            del data["output shape"]
            #print()

        elif workload_name in ["max_pool2d", "avg_pool2d"]:
            data["pool_0"] = data["pool_size"][0]
            data["pool_1"] = data["pool_size"][1]
            del data["pool_size"]

        if workload_name in ["max_pool2d", "avg_pool2d", "conv2d", "dilated_conv2d", "depthwise_conv2d"]:
            del data["padding"]
            data["C_I"] = data["input shape"][3]
            data["H_I"] = data["input shape"][1]
            data["W_I"] = data["input shape"][2]
            del data["input shape"]

            data["C_O"] = data["output shape"][3]
            data["H_O"] = data["output shape"][1]
            data["W_O"] = data["output shape"][2]
            del data["output shape"]

            key = "strides"
            if "stride" in data.keys():
                key = "stride"
            #print(key)
            data["strides_0"] = data[key][0]
            data["strides_1"] = data[key][1]
            del data["strides"]
            if "stride" in data.keys():
                del data["stride"]

        dataset[file] = data

    return dataset

def create_dataframe(dataset : dict, workload_name : str, labels = ["time", "power", "memory"]):
    df = pd.DataFrame.from_dict(dataset, orient='index')
    categoricals = [
        "output dtype",
        "compute dtype",
        "workload",
        ]
    if workload_name in ["conv2d", "max_pool2d", "avg_pool2d", "depthwise_conv2d", "dilated_conv2d"]:
        if "data_layout" in list(df.columns):
            categoricals += [
                #"padding",
                "data_layout",
            ]
        else:    
            categoricals += [
                #"padding",
                "data layout",
            ]
        

    if "conv2d" in workload_name:
        if "kernel_layout" in list(df.columns):
            categoricals += [
                "kernel_layout",
            ]
        if "kernel layout" in list(df.columns):
            categoricals += [
                "kernel layout",
            ]

    for col in categoricals:
        oh = pd.get_dummies(df[col], prefix=col, drop_first=False)
        df = pd.concat([df, oh], axis=1).drop(col, axis=1)
    
    features = list(df.columns)
    #labels = ["time", "power", "memory"]
    for label in labels:
        idx = features.index(label)
        del features[idx]
    del idx
    df = df.drop_duplicates(subset=features)

    label_data = []
    for label in labels:
        label_data.append(df[label])
        df.pop(label)

    output = pd.concat(label_data, axis=1)

    return df, output

# %%
# !ls dataset/
# Out:
#  cuda_980ti			     'llvm -mcpu=haswell_i7-4790'
#  cuda_A100			      opencl_Mali-T628_MP6
#  cuda_K80			      opencl_Mali-T628_MP6_no_power
# 'llvm -mcpu=haswell_E5-2680'	      rasp4b
# 'llvm -mcpu=haswell_E5-2680_faulty'

# %%
dataset_base = "./dataset"
targets = os.listdir(dataset_base)

layer_targets = list()
for target in targets:
    target_path = dataset_base + "/" + target
    layers = os.listdir(target_path)
    
    for layer in layers:
        dataset_path = target_path + "/" + layer + "/"
        print(dataset_path)
        layer_targets.append(dataset_path)

print("found {0} folders with samples, going to train models for each of these targets".format(len(layer_targets)))
print()
# Out:
# ./dataset/cuda_980ti/avg_pool2d/
# ./dataset/cuda_980ti/conv2d/
# ./dataset/cuda_980ti/dense/
# ./dataset/cuda_980ti/depthwise_conv2d/
# ./dataset/cuda_980ti/dilated_conv2d/
# ./dataset/cuda_980ti/max_pool2d/
# ./dataset/cuda_A100/avg_pool2d/
# ./dataset/cuda_A100/conv2d/
# ./dataset/cuda_A100/dense/
# ./dataset/cuda_A100/depthwise_conv2d/
# ./dataset/cuda_A100/dilated_conv2d/
# ./dataset/cuda_A100/max_pool2d/
# ./dataset/cuda_K80/avg_pool2d/
# ./dataset/cuda_K80/conv2d/
# ./dataset/cuda_K80/dense/
# ./dataset/cuda_K80/depthwise_conv2d/
# ./dataset/cuda_K80/dilated_conv2d/
# ./dataset/cuda_K80/max_pool2d/
# ./dataset/llvm -mcpu=haswell_E5-2680/avg_pool2d/
# ./dataset/llvm -mcpu=haswell_E5-2680/conv2d/
# ./dataset/llvm -mcpu=haswell_E5-2680/dense/
# ./dataset/llvm -mcpu=haswell_E5-2680/depthwise_conv2d/
# ./dataset/llvm -mcpu=haswell_E5-2680/dilated_conv2d/
# ./dataset/llvm -mcpu=haswell_E5-2680/max_pool2d/
# ./dataset/llvm -mcpu=haswell_E5-2680_faulty/conv2d/
# ./dataset/llvm -mcpu=haswell_E5-2680_faulty/dense/
# ./dataset/llvm -mcpu=haswell_E5-2680_faulty/depthwise_conv2d/
# ./dataset/llvm -mcpu=haswell_E5-2680_faulty/dilated_conv2d/
# ./dataset/llvm -mcpu=haswell_i7-4790/avg_pool2d/
# ./dataset/llvm -mcpu=haswell_i7-4790/conv2d/
# ./dataset/llvm -mcpu=haswell_i7-4790/max_pool2d/
# ./dataset/opencl_Mali-T628_MP6/avg_pool2d/
# ./dataset/opencl_Mali-T628_MP6/conv2d/
# ./dataset/opencl_Mali-T628_MP6/dense/
# ./dataset/opencl_Mali-T628_MP6/depthwise_conv2d/
# ./dataset/opencl_Mali-T628_MP6/dilated_conv2d/
# ./dataset/opencl_Mali-T628_MP6/max_pool2d/
# ./dataset/opencl_Mali-T628_MP6_no_power/conv2d/
# ./dataset/opencl_Mali-T628_MP6_no_power/dense/
# ./dataset/opencl_Mali-T628_MP6_no_power/depthwise_conv2d/
# ./dataset/rasp4b/conv2d/
# ./dataset/rasp4b/dilated_conv2d/
# found 42 folders with samples, going to train models for each of these targets

# %%
layer_targets = [
"./dataset/cuda_980ti/avg_pool2d/",
"./dataset/cuda_980ti/conv2d/",
"./dataset/cuda_980ti/dense/",
"./dataset/cuda_980ti/depthwise_conv2d/",
"./dataset/cuda_980ti/dilated_conv2d/",
"./dataset/cuda_980ti/max_pool2d/",
]

# %%
models = {
    "xgb": xgb.XGBRegressor,
    "ert": ExtraTreesRegressor,
    "dTr": DecisionTreeRegressor,
    "liR": LinearRegression,
    "kNN": KNeighborsRegressor,
    "SVR": SVR,
    "MLP": MLPRegressor,
}

kwargs_dict = {
    "xgb": None,
    "ert": {"n_estimators":175},
    "dTr": {"criterion":"mae", },
    "liR": {"normalize": True, "n_jobs":-1},
    "kNN": {"n_neighbors":3, "weights":"distance"},
    "SVR": {},
    "MLP": {"hidden_layer_sizes":(100,400,200,100,), "max_iter":500},
}

results = {}

# %%
for target in layer_targets:
    print(target)
    tmp = target.split("/")
    workload_name = tmp[-2]
    device_name = tmp[-3]
    files = os.listdir(target)
    dataset = {}
    
    labels = ["time", "power", "memory"]
    if device_name == "rasp4b" or device_name == "opencl_Mali-T628_MP6":
        labels = ["time", "power", "ws_size", "io_size"]
    
    print("{} : {}\t:\t contains {} samples".format(workload_name, device_name, len(files)))
    dataset = prepare_dataset(target, workload_name)
    df, output = create_dataframe(dataset, workload_name, labels=labels)
    print("\t[INFO] Remaining Samples after duplicate elimination:\t{}".format(len(df)))
    X = df.to_numpy()
    Y = output.to_numpy()
    labels = list(output.columns)

    X_train, X_test, y_train, y_test = train_test_split(X,Y, test_size=0.2)
    steps = 25
    start = step_size = len(X_train)//steps
    end = len(X_train)
    #scoring = ["r2", "neg_mean_absolute_error", "neg_mean_absolute_percentage_error", "max_error", "neg_median_absolute_error"]
    for method, constructor in models.items():
        for idx, name in enumerate(labels):
            for train_size in range(start, end, step_size):
                print(device_name)
                print(workload_name)
                print(name)
                print(method)
                print(train_size)

                if kwargs_dict[method] != None:
                    model = make_pipeline(RobustScaler(), constructor(**kwargs_dict[method]))
                else:
                    model = make_pipeline(RobustScaler(), constructor())

                model.fit(X_train[0:train_size], y_train[0:train_size,idx])
                pred_test = model.predict(X_test)
                r2_test = r2_score(y_test[:,idx], pred_test)
                max_error = np.max(np.abs(pred_test))
                mae = mean_absolute_error(y_test[:,idx], pred_test)
                mape = mean_absolute_percentage_error(y_test[:,idx], pred_test)
                medae = median_absolute_error(y_test[:,idx], pred_test)
                result = {
                    "device" : device_name,
                    "workload" : workload_name,
                    "metric" : name,
                    "predictor" : method,
                    "r2" : r2_test,
                    "max_error" : max_error,
                    "mae" : mae,
                    "mape" : mape,
                    "medae" : medae,
                    "dataset_min" : y_train[0:train_size,idx].min(),
                    "dataset_max" : y_train[0:train_size,idx].max(),
                    "dataset_mean" : y_train[0:train_size,idx].mean(),
                    "dataset_median" : np.median(y_train[:,idx]),
                    "dataset_size": train_size,
                }
                print(result)
                #print("R2: {.3f}\tMAE {.3f}\tMAPE {.3f}\tMEDAE {.3f}\tMaxError {.3f}".format(result["r2"],result["mae"],result["mape"],result["medae"],result["max_error"]))
                results[device_name+"-"+workload_name+"-"+name+"-"+method+":"+str(train_size)] = result
# Out:
# ./dataset/cuda_980ti/avg_pool2d/
# avg_pool2d : cuda_980ti	:	 contains 4692 samples
# 	[INFO] Remaining Samples after duplicate elimination:	4692
# cuda_980ti
# avg_pool2d
# time
# xgb
# 150
# {'device': 'cuda_980ti', 'workload': 'avg_pool2d', 'metric': 'time', 'predictor': 'xgb', 'r2': 0.6257710168089552, 'max_error': 15.85395, 'mae': 1.577896561294979, 'mape': 1.9005720069056025, 'medae': 0.7851575223541256, 'dataset_min': 0.00764443, 'dataset_max': 22.7072, 'dataset_mean': 3.7938289555333338, 'dataset_median': 1.45204, 'dataset_size': 150}
# cuda_980ti
# avg_pool2d
# time
# xgb
# 300
# {'device': 'cuda_980ti', 'workload': 'avg_pool2d', 'metric': 'time', 'predictor': 'xgb', 'r2': 0.7546991988212559, 'max_error': 17.626747, 'mae': 1.2195044549344791, 'mape': 1.408373192533336, 'medae': 0.5732872058105469, 'dataset_min': 0.006952310000000001, 'dataset_max': 27.1845, 'dataset_mean': 3.511813319866667, 'dataset_median': 1.45204, 'dataset_size': 300}
# cuda_980ti
# avg_pool2d
# time
# xgb
# 450
# {'device': 'cuda_980ti', 'workload': 'avg_pool2d', 'metric': 'time', 'predictor': 'xgb', 'r2': 0.7567772642062568, 'max_error': 19.001062, 'mae': 1.1687347235498171, 'mape': 1.29449468967597, 'medae': 0.4795612487792962, 'dataset_min': 0.006952310000000001, 'dataset_max': 27.1845, 'dataset_mean': 3.3289255929333335, 'dataset_median': 1.45204, 'dataset_size': 450}
# cuda_980ti
# avg_pool2d
# time
# xgb
# 600
# {'device': 'cuda_980ti', 'workload': 'avg_pool2d', 'metric': 'time', 'predictor': 'xgb', 'r2': 0.7882045990095131, 'max_error': 19.164679, 'mae': 1.1112944223092274, 'mape': 1.3003198496420494, 'medae': 0.4734109216403961, 'dataset_min': 0.006952310000000001, 'dataset_max': 27.1845, 'dataset_mean': 3.2344332163666674, 'dataset_median': 1.45204, 'dataset_size': 600}
# cuda_980ti
# avg_pool2d
# time
# xgb
# 750
# {'device': 'cuda_980ti', 'workload': 'avg_pool2d', 'metric': 'time', 'predictor': 'xgb', 'r2': 0.8352446368972529, 'max_error': 20.187054, 'mae': 0.976010409213089, 'mape': 1.161967875613108, 'medae': 0.45552450803756717, 'dataset_min': 0.006952310000000001, 'dataset_max': 27.1845, 'dataset_mean': 3.2025548994400004, 'dataset_median': 1.45204, 'dataset_size': 750}
# cuda_980ti
# avg_pool2d
# time
# xgb
# 900
# {'device': 'cuda_980ti', 'workload': 'avg_pool2d', 'metric': 'time', 'predictor': 'xgb', 'r2': 0.8479059776986835, 'max_error': 18.921377, 'mae': 0.9311660272817197, 'mape': 1.0571380780337112, 'medae': 0.4277711932296753, 'dataset_min': 0.006952310000000001, 'dataset_max': 27.1845, 'dataset_mean': 3.2124853026222224, 'dataset_median': 1.45204, 'dataset_size': 900}
# cuda_980ti
# avg_pool2d
# time
# xgb
# 1050
# {'device': 'cuda_980ti', 'workload': 'avg_pool2d', 'metric': 'time', 'predictor': 'xgb', 'r2': 0.8690698820405196, 'max_error': 23.433704, 'mae': 0.8745502870460221, 'mape': 1.1645670763326745, 'medae': 0.43168845405769346, 'dataset_min': 0.006952310000000001, 'dataset_max': 37.962999999999994, 'dataset_mean': 3.3085905682476184, 'dataset_median': 1.45204, 'dataset_size': 1050}
# cuda_980ti
# avg_pool2d
# time
# xgb
# 1200
# {'device': 'cuda_980ti', 'workload': 'avg_pool2d', 'metric': 'time', 'predictor': 'xgb', 'r2': 0.8637941441311894, 'max_error': 26.30755, 'mae': 0.9031604183250617, 'mape': 1.1484186656456536, 'medae': 0.449068894042969, 'dataset_min': 0.006952310000000001, 'dataset_max': 37.962999999999994, 'dataset_mean': 3.3291847553500005, 'dataset_median': 1.45204, 'dataset_size': 1200}
# cuda_980ti
# avg_pool2d
# time
# xgb
# 1350
# {'device': 'cuda_980ti', 'workload': 'avg_pool2d', 'metric': 'time', 'predictor': 'xgb', 'r2': 0.8851609219826815, 'max_error': 25.009815, 'mae': 0.8040120977896451, 'mape': 1.0140861037113804, 'medae': 0.37655151863098135, 'dataset_min': 0.006952310000000001, 'dataset_max': 37.962999999999994, 'dataset_mean': 3.2708506505407406, 'dataset_median': 1.45204, 'dataset_size': 1350}
# cuda_980ti
# avg_pool2d
# time
# xgb
# 1500
# {'device': 'cuda_980ti', 'workload': 'avg_pool2d', 'metric': 'time', 'predictor': 'xgb', 'r2': 0.8940548693949497, 'max_error': 20.164694, 'mae': 0.8023395395446072, 'mape': 1.0376671974552043, 'medae': 0.40178009471244813, 'dataset_min': 0.006952310000000001, 'dataset_max': 37.962999999999994, 'dataset_mean': 3.301799913266667, 'dataset_median': 1.45204, 'dataset_size': 1500}
# cuda_980ti
# avg_pool2d
# time
# xgb
# 1650
# {'device': 'cuda_980ti', 'workload': 'avg_pool2d', 'metric': 'time', 'predictor': 'xgb', 'r2': 0.8955855894957293, 'max_error': 23.822672, 'mae': 0.7746982797487796, 'mape': 0.9797281595185724, 'medae': 0.4036181799316405, 'dataset_min': 0.006952310000000001, 'dataset_max': 37.962999999999994, 'dataset_mean': 3.2749791628181817, 'dataset_median': 1.45204, 'dataset_size': 1650}
# cuda_980ti
# avg_pool2d
# time
# xgb
# 1800
# {'device': 'cuda_980ti', 'workload': 'avg_pool2d', 'metric': 'time', 'predictor': 'xgb', 'r2': 0.8916129698377151, 'max_error': 23.315063, 'mae': 0.7606346781397123, 'mape': 0.8913904911093089, 'medae': 0.3346283492813111, 'dataset_min': 0.006952310000000001, 'dataset_max': 37.962999999999994, 'dataset_mean': 3.3135287985833335, 'dataset_median': 1.45204, 'dataset_size': 1800}
# cuda_980ti
# avg_pool2d
# time
# xgb
# 1950
# {'device': 'cuda_980ti', 'workload': 'avg_pool2d', 'metric': 'time', 'predictor': 'xgb', 'r2': 0.9028089038729302, 'max_error': 22.563272, 'mae': 0.7375965061205937, 'mape': 0.9430898716300186, 'medae': 0.3685459552879333, 'dataset_min': 0.006952310000000001, 'dataset_max': 37.962999999999994, 'dataset_mean': 3.281242543307692, 'dataset_median': 1.45204, 'dataset_size': 1950}
# cuda_980ti
# avg_pool2d
# time
# xgb
# 2100
# {'device': 'cuda_980ti', 'workload': 'avg_pool2d', 'metric': 'time', 'predictor': 'xgb', 'r2': 0.9139805506332663, 'max_error': 18.821875, 'mae': 0.6988020573352558, 'mape': 0.9740915505269168, 'medae': 0.3505789497842789, 'dataset_min': 0.006952310000000001, 'dataset_max': 37.962999999999994, 'dataset_mean': 3.289532160752381, 'dataset_median': 1.45204, 'dataset_size': 2100}
# cuda_980ti
# avg_pool2d
# time
# xgb
# 2250
# {'device': 'cuda_980ti', 'workload': 'avg_pool2d', 'metric': 'time', 'predictor': 'xgb', 'r2': 0.9169125033294567, 'max_error': 18.255835, 'mae': 0.7019065345624023, 'mape': 0.9822790418687044, 'medae': 0.35504112345504757, 'dataset_min': 0.006952310000000001, 'dataset_max': 37.962999999999994, 'dataset_mean': 3.2620990307377777, 'dataset_median': 1.45204, 'dataset_size': 2250}
# cuda_980ti
# avg_pool2d
# time
# xgb
# 2400
# {'device': 'cuda_980ti', 'workload': 'avg_pool2d', 'metric': 'time', 'predictor': 'xgb', 'r2': 0.9171105335633157, 'max_error': 19.914686, 'mae': 0.6819786919146624, 'mape': 0.8576087792526971, 'medae': 0.3378131468910217, 'dataset_min': 0.006952310000000001, 'dataset_max': 37.962999999999994, 'dataset_mean': 3.2528571319333337, 'dataset_median': 1.45204, 'dataset_size': 2400}
# cuda_980ti
# avg_pool2d
# time
# xgb
# 2550
# {'device': 'cuda_980ti', 'workload': 'avg_pool2d', 'metric': 'time', 'predictor': 'xgb', 'r2': 0.9173757113284936, 'max_error': 20.29643, 'mae': 0.6965696563480319, 'mape': 0.9659800223577039, 'medae': 0.36573671475982666, 'dataset_min': 0.006952310000000001, 'dataset_max': 37.962999999999994, 'dataset_mean': 3.258631113203921, 'dataset_median': 1.45204, 'dataset_size': 2550}
# cuda_980ti
# avg_pool2d
# time
# xgb
# 2700
# {'device': 'cuda_980ti', 'workload': 'avg_pool2d', 'metric': 'time', 'predictor': 'xgb', 'r2': 0.926954622666225, 'max_error': 22.547071, 'mae': 0.6618249770705583, 'mape': 1.033886626318382, 'medae': 0.3578885038032531, 'dataset_min': 0.006952310000000001, 'dataset_max': 37.962999999999994, 'dataset_mean': 3.2745152525666668, 'dataset_median': 1.45204, 'dataset_size': 2700}
# cuda_980ti
# avg_pool2d
# time
# xgb
# 2850
# {'device': 'cuda_980ti', 'workload': 'avg_pool2d', 'metric': 'time', 'predictor': 'xgb', 'r2': 0.9272621293252181, 'max_error': 21.175934, 'mae': 0.6477517188162416, 'mape': 0.8442880960253552, 'medae': 0.32705954910278345, 'dataset_min': 0.006952310000000001, 'dataset_max': 37.962999999999994, 'dataset_mean': 3.2536782168666667, 'dataset_median': 1.45204, 'dataset_size': 2850}
# cuda_980ti
# avg_pool2d
# time
# xgb
# 3000
# {'device': 'cuda_980ti', 'workload': 'avg_pool2d', 'metric': 'time', 'predictor': 'xgb', 'r2': 0.9288738296500894, 'max_error': 19.279247, 'mae': 0.638234408474013, 'mape': 0.8341735662988408, 'medae': 0.330604188537599, 'dataset_min': 0.006952310000000001, 'dataset_max': 37.962999999999994, 'dataset_mean': 3.2667043546466665, 'dataset_median': 1.45204, 'dataset_size': 3000}
# cuda_980ti
# avg_pool2d
# time
# xgb
# 3150
# {'device': 'cuda_980ti', 'workload': 'avg_pool2d', 'metric': 'time', 'predictor': 'xgb', 'r2': 0.9332443053656827, 'max_error': 20.442993, 'mae': 0.647088856801748, 'mape': 0.870793830119171, 'medae': 0.3555919998168946, 'dataset_min': 0.006952310000000001, 'dataset_max': 37.962999999999994, 'dataset_mean': 3.2996337352190475, 'dataset_median': 1.45204, 'dataset_size': 3150}
# cuda_980ti
# avg_pool2d
# time
# xgb
# 3300
# {'device': 'cuda_980ti', 'workload': 'avg_pool2d', 'metric': 'time', 'predictor': 'xgb', 'r2': 0.9389018124490888, 'max_error': 21.021982, 'mae': 0.6097536931578752, 'mape': 0.897174036073563, 'medae': 0.3176828628425598, 'dataset_min': 0.006952310000000001, 'dataset_max': 37.962999999999994, 'dataset_mean': 3.3021381612060603, 'dataset_median': 1.45204, 'dataset_size': 3300}
# cuda_980ti
# avg_pool2d
# time
# xgb
# 3450
# {'device': 'cuda_980ti', 'workload': 'avg_pool2d', 'metric': 'time', 'predictor': 'xgb', 'r2': 0.9450125306126885, 'max_error': 19.309673, 'mae': 0.5670209864160767, 'mape': 0.8685304526024984, 'medae': 0.2904706708335877, 'dataset_min': 0.006952310000000001, 'dataset_max': 37.962999999999994, 'dataset_mean': 3.315981096333333, 'dataset_median': 1.45204, 'dataset_size': 3450}
# cuda_980ti
# avg_pool2d
# time
# xgb
# 3600
# {'device': 'cuda_980ti', 'workload': 'avg_pool2d', 'metric': 'time', 'predictor': 'xgb', 'r2': 0.9388008433336938, 'max_error': 19.416866, 'mae': 0.5993323172684174, 'mape': 0.7967885666028224, 'medae': 0.2984884190368653, 'dataset_min': 0.006952310000000001, 'dataset_max': 37.962999999999994, 'dataset_mean': 3.306652801097222, 'dataset_median': 1.45204, 'dataset_size': 3600}
# cuda_980ti
# avg_pool2d
# time
# xgb
# 3750
# {'device': 'cuda_980ti', 'workload': 'avg_pool2d', 'metric': 'time', 'predictor': 'xgb', 'r2': 0.9387793868502479, 'max_error': 18.691687, 'mae': 0.6076183510088317, 'mape': 0.900786318937246, 'medae': 0.3279508712768546, 'dataset_min': 0.006952310000000001, 'dataset_max': 37.962999999999994, 'dataset_mean': 3.3122291159253336, 'dataset_median': 1.45204, 'dataset_size': 3750}
# cuda_980ti
# avg_pool2d
# power
# xgb
# 150
# {'device': 'cuda_980ti', 'workload': 'avg_pool2d', 'metric': 'power', 'predictor': 'xgb', 'r2': 0.8208148261310563, 'max_error': 203.63835, 'mae': 5.607163618548863, 'mape': 0.03580472924583753, 'medae': 3.602816406250014, 'dataset_min': 125.057, 'dataset_max': 206.60199999999998, 'dataset_mean': 160.4425733333333, 'dataset_median': 152.711, 'dataset_size': 150}
# cuda_980ti
# avg_pool2d
# power
# xgb
# 300
# {'device': 'cuda_980ti', 'workload': 'avg_pool2d', 'metric': 'power', 'predictor': 'xgb', 'r2': 0.7023819119951603, 'max_error': 203.41461, 'mae': 5.688937495579988, 'mape': 0.03580642428660828, 'medae': 3.213566650390618, 'dataset_min': 100.725, 'dataset_max': 206.60199999999998, 'dataset_mean': 160.88518666666667, 'dataset_median': 152.711, 'dataset_size': 300}
# cuda_980ti
# avg_pool2d
# power
# xgb
# 450
# {'device': 'cuda_980ti', 'workload': 'avg_pool2d', 'metric': 'power', 'predictor': 'xgb', 'r2': 0.7881348405350177, 'max_error': 203.8876, 'mae': 5.041847681340064, 'mape': 0.03179566824247295, 'medae': 2.7058234863281143, 'dataset_min': 100.725, 'dataset_max': 206.60199999999998, 'dataset_mean': 160.04152999999997, 'dataset_median': 152.711, 'dataset_size': 450}
# cuda_980ti
# avg_pool2d
# power
# xgb
# 600
# {'device': 'cuda_980ti', 'workload': 'avg_pool2d', 'metric': 'power', 'predictor': 'xgb', 'r2': 0.8440107249172356, 'max_error': 204.02242, 'mae': 4.484167839919671, 'mape': 0.028544189240320976, 'medae': 2.489308593749996, 'dataset_min': 65.936, 'dataset_max': 206.60199999999998, 'dataset_mean': 160.2731725, 'dataset_median': 152.711, 'dataset_size': 600}
# cuda_980ti
# avg_pool2d
# power
# xgb
# 750
# {'device': 'cuda_980ti', 'workload': 'avg_pool2d', 'metric': 'power', 'predictor': 'xgb', 'r2': 0.8401723311465313, 'max_error': 205.11438, 'mae': 4.462353641335322, 'mape': 0.028479380898012798, 'medae': 2.5430172119140764, 'dataset_min': 65.936, 'dataset_max': 206.60199999999998, 'dataset_mean': 160.58695, 'dataset_median': 152.711, 'dataset_size': 750}
# cuda_980ti
# avg_pool2d
# power
# xgb
# 900
# {'device': 'cuda_980ti', 'workload': 'avg_pool2d', 'metric': 'power', 'predictor': 'xgb', 'r2': 0.8597146698419588, 'max_error': 204.42162, 'mae': 4.132936182901628, 'mape': 0.02650712774666527, 'medae': 2.2645675048828195, 'dataset_min': 65.936, 'dataset_max': 206.60199999999998, 'dataset_mean': 160.8456866666667, 'dataset_median': 152.711, 'dataset_size': 900}
# cuda_980ti
# avg_pool2d
# power
# xgb
# 1050
# {'device': 'cuda_980ti', 'workload': 'avg_pool2d', 'metric': 'power', 'predictor': 'xgb', 'r2': 0.9002054542454911, 'max_error': 204.91109, 'mae': 3.759212118683023, 'mape': 0.024110079915601355, 'medae': 2.2338197021484234, 'dataset_min': 65.936, 'dataset_max': 207.30149999999998, 'dataset_mean': 161.09278285714288, 'dataset_median': 152.711, 'dataset_size': 1050}
# cuda_980ti
# avg_pool2d
# power
# xgb
# 1200
# {'device': 'cuda_980ti', 'workload': 'avg_pool2d', 'metric': 'power', 'predictor': 'xgb', 'r2': 0.9101354027772685, 'max_error': 209.54626, 'mae': 3.5883227685962877, 'mape': 0.022964117930326534, 'medae': 2.035429199218754, 'dataset_min': 65.936, 'dataset_max': 207.30149999999998, 'dataset_mean': 160.87049416666667, 'dataset_median': 152.711, 'dataset_size': 1200}
# cuda_980ti
# avg_pool2d
# power
# xgb
# 1350
# {'device': 'cuda_980ti', 'workload': 'avg_pool2d', 'metric': 'power', 'predictor': 'xgb', 'r2': 0.9243878857948581, 'max_error': 205.56418, 'mae': 3.3307914168710266, 'mape': 0.021318307485288512, 'medae': 1.8710627441406302, 'dataset_min': 65.936, 'dataset_max': 207.30149999999998, 'dataset_mean': 160.59396407407408, 'dataset_median': 152.711, 'dataset_size': 1350}
# cuda_980ti
# avg_pool2d
# power
# xgb
# 1500
# {'device': 'cuda_980ti', 'workload': 'avg_pool2d', 'metric': 'power', 'predictor': 'xgb', 'r2': 0.9183031513044175, 'max_error': 207.2495, 'mae': 3.266308877280726, 'mape': 0.020985218371327028, 'medae': 1.806422363281257, 'dataset_min': 65.936, 'dataset_max': 207.30149999999998, 'dataset_mean': 160.54250499999998, 'dataset_median': 152.711, 'dataset_size': 1500}
# cuda_980ti
# avg_pool2d
# power
# xgb
# 1650
# {'device': 'cuda_980ti', 'workload': 'avg_pool2d', 'metric': 'power', 'predictor': 'xgb', 'r2': 0.9231676482757041, 'max_error': 206.14893, 'mae': 3.2289502123425438, 'mape': 0.02054645432665433, 'medae': 1.7889831542968864, 'dataset_min': 65.936, 'dataset_max': 207.30149999999998, 'dataset_mean': 160.6716572727273, 'dataset_median': 152.711, 'dataset_size': 1650}
# cuda_980ti
# avg_pool2d
# power
# xgb
# 1800
# {'device': 'cuda_980ti', 'workload': 'avg_pool2d', 'metric': 'power', 'predictor': 'xgb', 'r2': 0.9136131780898282, 'max_error': 207.56627, 'mae': 3.312818440560208, 'mape': 0.02114326382211674, 'medae': 1.7817509765624777, 'dataset_min': 65.936, 'dataset_max': 207.30149999999998, 'dataset_mean': 160.71906444444443, 'dataset_median': 152.711, 'dataset_size': 1800}
# cuda_980ti
# avg_pool2d
# power
# xgb
# 1950
# {'device': 'cuda_980ti', 'workload': 'avg_pool2d', 'metric': 'power', 'predictor': 'xgb', 'r2': 0.9216223757279816, 'max_error': 206.97461, 'mae': 3.224514248361476, 'mape': 0.020404660177101255, 'medae': 1.846725708007824, 'dataset_min': 65.936, 'dataset_max': 207.30149999999998, 'dataset_mean': 160.67326564102564, 'dataset_median': 152.711, 'dataset_size': 1950}
# cuda_980ti
# avg_pool2d
# power
# xgb
# 2100
# {'device': 'cuda_980ti', 'workload': 'avg_pool2d', 'metric': 'power', 'predictor': 'xgb', 'r2': 0.9409130639089396, 'max_error': 207.63869, 'mae': 2.9549569462947827, 'mape': 0.018803865803545483, 'medae': 1.6379458007812389, 'dataset_min': 65.936, 'dataset_max': 207.30149999999998, 'dataset_mean': 160.62340214285715, 'dataset_median': 152.711, 'dataset_size': 2100}
# cuda_980ti
# avg_pool2d
# power
# xgb
# 2250
# {'device': 'cuda_980ti', 'workload': 'avg_pool2d', 'metric': 'power', 'predictor': 'xgb', 'r2': 0.9341138686432445, 'max_error': 205.37419, 'mae': 2.9377184049141167, 'mape': 0.01882342559816793, 'medae': 1.623147094726562, 'dataset_min': 65.936, 'dataset_max': 207.30149999999998, 'dataset_mean': 160.61781844444442, 'dataset_median': 152.711, 'dataset_size': 2250}
# cuda_980ti
# avg_pool2d
# power
# xgb
# 2400
# {'device': 'cuda_980ti', 'workload': 'avg_pool2d', 'metric': 'power', 'predictor': 'xgb', 'r2': 0.9421610204383002, 'max_error': 206.50513, 'mae': 2.8096637102640987, 'mape': 0.01800722224776287, 'medae': 1.6602138671875082, 'dataset_min': 65.936, 'dataset_max': 207.30149999999998, 'dataset_mean': 160.49493770833334, 'dataset_median': 152.711, 'dataset_size': 2400}
# cuda_980ti
# avg_pool2d
# power
# xgb
# 2550
# {'device': 'cuda_980ti', 'workload': 'avg_pool2d', 'metric': 'power', 'predictor': 'xgb', 'r2': 0.9479162819465792, 'max_error': 206.21948, 'mae': 2.772180587492304, 'mape': 0.017747241861432346, 'medae': 1.6288853759765516, 'dataset_min': 65.936, 'dataset_max': 207.30149999999998, 'dataset_mean': 160.48875137254902, 'dataset_median': 152.711, 'dataset_size': 2550}
# cuda_980ti
# avg_pool2d
# power
# xgb
# 2700
# {'device': 'cuda_980ti', 'workload': 'avg_pool2d', 'metric': 'power', 'predictor': 'xgb', 'r2': 0.9419479211762092, 'max_error': 207.05943, 'mae': 2.702181562234799, 'mape': 0.01726182024175429, 'medae': 1.4074025878906298, 'dataset_min': 65.936, 'dataset_max': 207.30149999999998, 'dataset_mean': 160.6372562962963, 'dataset_median': 152.711, 'dataset_size': 2700}
# cuda_980ti
# avg_pool2d
# power
# xgb
# 2850
# {'device': 'cuda_980ti', 'workload': 'avg_pool2d', 'metric': 'power', 'predictor': 'xgb', 'r2': 0.9559718960837298, 'max_error': 205.0119, 'mae': 2.5381846727527617, 'mape': 0.016250366130512447, 'medae': 1.3287701416015523, 'dataset_min': 65.936, 'dataset_max': 207.30149999999998, 'dataset_mean': 160.76013684210525, 'dataset_median': 152.711, 'dataset_size': 2850}
# cuda_980ti
# avg_pool2d
# power
# xgb
# 3000
# {'device': 'cuda_980ti', 'workload': 'avg_pool2d', 'metric': 'power', 'predictor': 'xgb', 'r2': 0.9530384659154276, 'max_error': 204.17896, 'mae': 2.555428551752093, 'mape': 0.016472390607232452, 'medae': 1.3656303710937436, 'dataset_min': 65.936, 'dataset_max': 207.30149999999998, 'dataset_mean': 160.71441683333333, 'dataset_median': 152.711, 'dataset_size': 3000}
# cuda_980ti
# avg_pool2d
# power
# xgb
# 3150
# {'device': 'cuda_980ti', 'workload': 'avg_pool2d', 'metric': 'power', 'predictor': 'xgb', 'r2': 0.9548291290169872, 'max_error': 207.46326, 'mae': 2.5366563075901474, 'mape': 0.016173772293335668, 'medae': 1.3514772949218639, 'dataset_min': 65.936, 'dataset_max': 207.30149999999998, 'dataset_mean': 160.81766634920635, 'dataset_median': 152.711, 'dataset_size': 3150}
# cuda_980ti
# avg_pool2d
# power
# xgb
# 3300
# {'device': 'cuda_980ti', 'workload': 'avg_pool2d', 'metric': 'power', 'predictor': 'xgb', 'r2': 0.9587504579597632, 'max_error': 204.76457, 'mae': 2.451758208741014, 'mape': 0.015547326469143915, 'medae': 1.3120034179687536, 'dataset_min': 65.936, 'dataset_max': 207.30149999999998, 'dataset_mean': 160.87834090909095, 'dataset_median': 152.711, 'dataset_size': 3300}
# cuda_980ti
# avg_pool2d
# power
# xgb
# 3450
# {'device': 'cuda_980ti', 'workload': 'avg_pool2d', 'metric': 'power', 'predictor': 'xgb', 'r2': 0.9458873497284713, 'max_error': 205.38449, 'mae': 2.6298578478210906, 'mape': 0.01694234496593715, 'medae': 1.4100467529296736, 'dataset_min': 65.936, 'dataset_max': 207.30149999999998, 'dataset_mean': 160.89062869565217, 'dataset_median': 152.711, 'dataset_size': 3450}
# cuda_980ti
# avg_pool2d
# power
# xgb
# 3600
# {'device': 'cuda_980ti', 'workload': 'avg_pool2d', 'metric': 'power', 'predictor': 'xgb', 'r2': 0.960356628169811, 'max_error': 203.9823, 'mae': 2.421429517524565, 'mape': 0.015394356127648594, 'medae': 1.4025426025390573, 'dataset_min': 65.936, 'dataset_max': 207.30149999999998, 'dataset_mean': 160.88344930555556, 'dataset_median': 152.711, 'dataset_size': 3600}
# cuda_980ti
# avg_pool2d
# power
# xgb
# 3750
# {'device': 'cuda_980ti', 'workload': 'avg_pool2d', 'metric': 'power', 'predictor': 'xgb', 'r2': 0.959727564314307, 'max_error': 206.11809, 'mae': 2.3654223116061175, 'mape': 0.01499439723865959, 'medae': 1.4564012451171777, 'dataset_min': 65.936, 'dataset_max': 207.30149999999998, 'dataset_mean': 160.88531226666666, 'dataset_median': 152.711, 'dataset_size': 3750}
# cuda_980ti
# avg_pool2d
# memory
# xgb
# 150
# {'device': 'cuda_980ti', 'workload': 'avg_pool2d', 'metric': 'memory', 'predictor': 'xgb', 'r2': 0.696743100829688, 'max_error': 3.680906, 'mae': 0.3545259972295354, 'mape': 0.51750576211728, 'medae': 0.19032970070838928, 'dataset_min': 0.09796142578125, 'dataset_max': 3.95184326171875, 'dataset_mean': 1.0998347981770833, 'dataset_median': 0.50396728515625, 'dataset_size': 150}
# cuda_980ti
# avg_pool2d
# memory
# xgb
# 300
# {'device': 'cuda_980ti', 'workload': 'avg_pool2d', 'metric': 'memory', 'predictor': 'xgb', 'r2': 0.8189254107670015, 'max_error': 3.706348, 'mae': 0.27305061918712115, 'mape': 0.38951460367454077, 'medae': 0.14940637350082397, 'dataset_min': 0.09796142578125, 'dataset_max': 4.15838623046875, 'dataset_mean': 1.0091650390625, 'dataset_median': 0.50396728515625, 'dataset_size': 300}
# cuda_980ti
# avg_pool2d
# memory
# xgb
# 450
# {'device': 'cuda_980ti', 'workload': 'avg_pool2d', 'metric': 'memory', 'predictor': 'xgb', 'r2': 0.8324028860691003, 'max_error': 3.5826468, 'mae': 0.2511585885935331, 'mape': 0.3255665227164777, 'medae': 0.10721462965011597, 'dataset_min': 0.09796142578125, 'dataset_max': 4.15838623046875, 'dataset_mean': 0.9682633463541667, 'dataset_median': 0.50396728515625, 'dataset_size': 450}
# cuda_980ti
# avg_pool2d
# memory
# xgb
# 600
# {'device': 'cuda_980ti', 'workload': 'avg_pool2d', 'metric': 'memory', 'predictor': 'xgb', 'r2': 0.8659127695824644, 'max_error': 3.5696578, 'mae': 0.22228218420149304, 'mape': 0.290545204546436, 'medae': 0.10424553230404854, 'dataset_min': 0.09796142578125, 'dataset_max': 4.26934814453125, 'dataset_mean': 0.9532525634765625, 'dataset_median': 0.50396728515625, 'dataset_size': 600}
# cuda_980ti
# avg_pool2d
# memory
# xgb
# 750
# {'device': 'cuda_980ti', 'workload': 'avg_pool2d', 'metric': 'memory', 'predictor': 'xgb', 'r2': 0.9079783303383461, 'max_error': 3.5190928, 'mae': 0.19095437131877652, 'mape': 0.2618047539925818, 'medae': 0.09867432713508606, 'dataset_min': 0.09796142578125, 'dataset_max': 4.26934814453125, 'dataset_mean': 0.9501922200520834, 'dataset_median': 0.50396728515625, 'dataset_size': 750}
# cuda_980ti
# avg_pool2d
# memory
# xgb
# 900
# {'device': 'cuda_980ti', 'workload': 'avg_pool2d', 'metric': 'memory', 'predictor': 'xgb', 'r2': 0.9219487574943754, 'max_error': 3.5603666, 'mae': 0.17276219491369793, 'mape': 0.22964530578562037, 'medae': 0.08164635300636292, 'dataset_min': 0.09747314453125, 'dataset_max': 4.89947509765625, 'dataset_mean': 0.9524032931857639, 'dataset_median': 0.50396728515625, 'dataset_size': 900}
# cuda_980ti
# avg_pool2d
# memory
# xgb
# 1050
# {'device': 'cuda_980ti', 'workload': 'avg_pool2d', 'metric': 'memory', 'predictor': 'xgb', 'r2': 0.9260143760251516, 'max_error': 3.7371514, 'mae': 0.1687472513485085, 'mape': 0.23490534147167147, 'medae': 0.08689814805984497, 'dataset_min': 0.09747314453125, 'dataset_max': 4.89947509765625, 'dataset_mean': 0.9619056919642858, 'dataset_median': 0.50396728515625, 'dataset_size': 1050}
# cuda_980ti
# avg_pool2d
# memory
# xgb
# 1200
# {'device': 'cuda_980ti', 'workload': 'avg_pool2d', 'metric': 'memory', 'predictor': 'xgb', 'r2': 0.9283576565798836, 'max_error': 3.7695725, 'mae': 0.16298273275879085, 'mape': 0.22276494016369214, 'medae': 0.0808335542678833, 'dataset_min': 0.09747314453125, 'dataset_max': 4.89947509765625, 'dataset_mean': 0.9696247355143229, 'dataset_median': 0.50396728515625, 'dataset_size': 1200}
# cuda_980ti
# avg_pool2d
# memory
# xgb
# 1350
# {'device': 'cuda_980ti', 'workload': 'avg_pool2d', 'metric': 'memory', 'predictor': 'xgb', 'r2': 0.9342550791265343, 'max_error': 3.4604132, 'mae': 0.16027825264036022, 'mape': 0.22390531602176114, 'medae': 0.0799107626080513, 'dataset_min': 0.09747314453125, 'dataset_max': 4.89947509765625, 'dataset_mean': 0.9621580222800926, 'dataset_median': 0.50396728515625, 'dataset_size': 1350}
# cuda_980ti
# avg_pool2d
# memory
# xgb
# 1500
# {'device': 'cuda_980ti', 'workload': 'avg_pool2d', 'metric': 'memory', 'predictor': 'xgb', 'r2': 0.9397238645475359, 'max_error': 3.5052564, 'mae': 0.14987967441766498, 'mape': 0.22117330415012815, 'medae': 0.08146575093269348, 'dataset_min': 0.09747314453125, 'dataset_max': 4.89947509765625, 'dataset_mean': 0.97003076171875, 'dataset_median': 0.50396728515625, 'dataset_size': 1500}
# cuda_980ti
# avg_pool2d
# memory
# xgb
# 1650
# {'device': 'cuda_980ti', 'workload': 'avg_pool2d', 'metric': 'memory', 'predictor': 'xgb', 'r2': 0.9418564173517507, 'max_error': 3.5664635, 'mae': 0.15074007873868728, 'mape': 0.21975532798279593, 'medae': 0.08201861381530762, 'dataset_min': 0.09747314453125, 'dataset_max': 4.89947509765625, 'dataset_mean': 0.9647981770833334, 'dataset_median': 0.50396728515625, 'dataset_size': 1650}
# cuda_980ti
# avg_pool2d
# memory
# xgb
# 1800
# {'device': 'cuda_980ti', 'workload': 'avg_pool2d', 'metric': 'memory', 'predictor': 'xgb', 'r2': 0.9497048104417652, 'max_error': 3.683907, 'mae': 0.13755157690086622, 'mape': 0.1834626041096773, 'medae': 0.06587755307555199, 'dataset_min': 0.09747314453125, 'dataset_max': 4.89947509765625, 'dataset_mean': 0.9706834581163194, 'dataset_median': 0.50396728515625, 'dataset_size': 1800}
# cuda_980ti
# avg_pool2d
# memory
# xgb
# 1950
# {'device': 'cuda_980ti', 'workload': 'avg_pool2d', 'metric': 'memory', 'predictor': 'xgb', 'r2': 0.949587248064994, 'max_error': 3.516102, 'mae': 0.13867746738873668, 'mape': 0.19778532650106934, 'medae': 0.0736284852027893, 'dataset_min': 0.09747314453125, 'dataset_max': 4.89947509765625, 'dataset_mean': 0.9655535106169871, 'dataset_median': 0.50396728515625, 'dataset_size': 1950}
# cuda_980ti
# avg_pool2d
# memory
# xgb
# 2100
# {'device': 'cuda_980ti', 'workload': 'avg_pool2d', 'metric': 'memory', 'predictor': 'xgb', 'r2': 0.9498469943106438, 'max_error': 3.578653, 'mae': 0.1442238810840157, 'mape': 0.20956568876743417, 'medae': 0.08487215638160706, 'dataset_min': 0.09747314453125, 'dataset_max': 4.89947509765625, 'dataset_mean': 0.966610107421875, 'dataset_median': 0.50396728515625, 'dataset_size': 2100}
# cuda_980ti
# avg_pool2d
# memory
# xgb
# 2250
# {'device': 'cuda_980ti', 'workload': 'avg_pool2d', 'metric': 'memory', 'predictor': 'xgb', 'r2': 0.9498858184829123, 'max_error': 3.5735114, 'mae': 0.14410137400577586, 'mape': 0.20350363024119192, 'medae': 0.07974331080913544, 'dataset_min': 0.09747314453125, 'dataset_max': 4.89947509765625, 'dataset_mean': 0.9623943684895834, 'dataset_median': 0.50396728515625, 'dataset_size': 2250}
# cuda_980ti
# avg_pool2d
# memory
# xgb
# 2400
# {'device': 'cuda_980ti', 'workload': 'avg_pool2d', 'metric': 'memory', 'predictor': 'xgb', 'r2': 0.9525790235472448, 'max_error': 3.559427, 'mae': 0.1358765039634638, 'mape': 0.19031099144871105, 'medae': 0.07041263580322266, 'dataset_min': 0.09747314453125, 'dataset_max': 4.89947509765625, 'dataset_mean': 0.9617756144205729, 'dataset_median': 0.50396728515625, 'dataset_size': 2400}
# cuda_980ti
# avg_pool2d
# memory
# xgb
# 2550
# {'device': 'cuda_980ti', 'workload': 'avg_pool2d', 'metric': 'memory', 'predictor': 'xgb', 'r2': 0.9567961697745597, 'max_error': 3.735999, 'mae': 0.13177646648959992, 'mape': 0.19328196895330219, 'medae': 0.06972897052764893, 'dataset_min': 0.09747314453125, 'dataset_max': 4.89947509765625, 'dataset_mean': 0.9640247778799019, 'dataset_median': 0.50396728515625, 'dataset_size': 2550}
# cuda_980ti
# avg_pool2d
# memory
# xgb
# 2700
# {'device': 'cuda_980ti', 'workload': 'avg_pool2d', 'metric': 'memory', 'predictor': 'xgb', 'r2': 0.960176524870888, 'max_error': 3.5958023, 'mae': 0.12784694976701982, 'mape': 0.19033463242522744, 'medae': 0.06940540671348572, 'dataset_min': 0.09747314453125, 'dataset_max': 4.89947509765625, 'dataset_mean': 0.9678802264178241, 'dataset_median': 0.50396728515625, 'dataset_size': 2700}
# cuda_980ti
# avg_pool2d
# memory
# xgb
# 2850
# {'device': 'cuda_980ti', 'workload': 'avg_pool2d', 'metric': 'memory', 'predictor': 'xgb', 'r2': 0.9643573924265239, 'max_error': 3.6516833, 'mae': 0.1193978457559888, 'mape': 0.17487931738658735, 'medae': 0.06691297888755798, 'dataset_min': 0.09747314453125, 'dataset_max': 4.89947509765625, 'dataset_mean': 0.9600778680098684, 'dataset_median': 0.50396728515625, 'dataset_size': 2850}
# cuda_980ti
# avg_pool2d
# memory
# xgb
# 3000
# {'device': 'cuda_980ti', 'workload': 'avg_pool2d', 'metric': 'memory', 'predictor': 'xgb', 'r2': 0.9640947872694172, 'max_error': 3.6539555, 'mae': 0.11728639000009139, 'mape': 0.16773159780808988, 'medae': 0.060461580753326416, 'dataset_min': 0.09747314453125, 'dataset_max': 4.89947509765625, 'dataset_mean': 0.96086669921875, 'dataset_median': 0.50396728515625, 'dataset_size': 3000}
# cuda_980ti
# avg_pool2d
# memory
# xgb
# 3150
# {'device': 'cuda_980ti', 'workload': 'avg_pool2d', 'metric': 'memory', 'predictor': 'xgb', 'r2': 0.9614895718009405, 'max_error': 3.6450813, 'mae': 0.12609307491146146, 'mape': 0.1789020959709598, 'medae': 0.06870967149734497, 'dataset_min': 0.09747314453125, 'dataset_max': 4.89947509765625, 'dataset_mean': 0.968086906312004, 'dataset_median': 0.50396728515625, 'dataset_size': 3150}
# cuda_980ti
# avg_pool2d
# memory
# xgb
# 3300
# {'device': 'cuda_980ti', 'workload': 'avg_pool2d', 'metric': 'memory', 'predictor': 'xgb', 'r2': 0.9627651712023737, 'max_error': 3.540995, 'mae': 0.12276049286694414, 'mape': 0.1762014503057235, 'medae': 0.06805479526519775, 'dataset_min': 0.09747314453125, 'dataset_max': 4.89947509765625, 'dataset_mean': 0.9691931892163825, 'dataset_median': 0.50396728515625, 'dataset_size': 3300}
# cuda_980ti
# avg_pool2d
# memory
# xgb
# 3450
# {'device': 'cuda_980ti', 'workload': 'avg_pool2d', 'metric': 'memory', 'predictor': 'xgb', 'r2': 0.9643910449903279, 'max_error': 3.7817953, 'mae': 0.11773984606107013, 'mape': 0.1654846228668233, 'medae': 0.06215029954910278, 'dataset_min': 0.09747314453125, 'dataset_max': 4.89947509765625, 'dataset_mean': 0.9720152216372283, 'dataset_median': 0.50396728515625, 'dataset_size': 3450}
# cuda_980ti
# avg_pool2d
# memory
# xgb
# 3600
# {'device': 'cuda_980ti', 'workload': 'avg_pool2d', 'metric': 'memory', 'predictor': 'xgb', 'r2': 0.9636730565450086, 'max_error': 3.692575, 'mae': 0.1191986540431123, 'mape': 0.16779716564815755, 'medae': 0.06399518251419067, 'dataset_min': 0.09747314453125, 'dataset_max': 4.89947509765625, 'dataset_mean': 0.9705381605360243, 'dataset_median': 0.50396728515625, 'dataset_size': 3600}
# cuda_980ti
# avg_pool2d
# memory
# xgb
# 3750
# {'device': 'cuda_980ti', 'workload': 'avg_pool2d', 'metric': 'memory', 'predictor': 'xgb', 'r2': 0.9667493455681568, 'max_error': 3.6896873, 'mae': 0.11238612448727202, 'mape': 0.15733156653640062, 'medae': 0.05731773376464844, 'dataset_min': 0.09747314453125, 'dataset_max': 4.89947509765625, 'dataset_mean': 0.97035009765625, 'dataset_median': 0.50396728515625, 'dataset_size': 3750}
# cuda_980ti
# avg_pool2d
# time
# ert
# 150
# {'device': 'cuda_980ti', 'workload': 'avg_pool2d', 'metric': 'time', 'predictor': 'ert', 'r2': 0.623362510154388, 'max_error': 18.075102571428513, 'mae': 1.6653077795906888, 'mape': 2.68256205260656, 'medae': 1.0311526799999995, 'dataset_min': 0.00764443, 'dataset_max': 22.7072, 'dataset_mean': 3.7938289555333338, 'dataset_median': 1.45204, 'dataset_size': 150}
# cuda_980ti
# avg_pool2d
# time
# ert
# 300
# {'device': 'cuda_980ti', 'workload': 'avg_pool2d', 'metric': 'time', 'predictor': 'ert', 'r2': 0.7525407114416036, 'max_error': 17.03468959999997, 'mae': 1.2464033784660276, 'mape': 1.55986496884192, 'medae': 0.6843902685714296, 'dataset_min': 0.006952310000000001, 'dataset_max': 27.1845, 'dataset_mean': 3.511813319866667, 'dataset_median': 1.45204, 'dataset_size': 300}
# cuda_980ti
# avg_pool2d
# time
# ert
# 450
# {'device': 'cuda_980ti', 'workload': 'avg_pool2d', 'metric': 'time', 'predictor': 'ert', 'r2': 0.7412612141867031, 'max_error': 17.776464342857146, 'mae': 1.2026099040787461, 'mape': 1.2232562335097663, 'medae': 0.5688892628571419, 'dataset_min': 0.006952310000000001, 'dataset_max': 27.1845, 'dataset_mean': 3.3289255929333335, 'dataset_median': 1.45204, 'dataset_size': 450}
# cuda_980ti
# avg_pool2d
# time
# ert
# 600
# {'device': 'cuda_980ti', 'workload': 'avg_pool2d', 'metric': 'time', 'predictor': 'ert', 'r2': 0.7774223945299699, 'max_error': 18.263023502857095, 'mae': 1.136509922263015, 'mape': 1.0318117730539842, 'medae': 0.5566961502857144, 'dataset_min': 0.006952310000000001, 'dataset_max': 27.1845, 'dataset_mean': 3.2344332163666674, 'dataset_median': 1.45204, 'dataset_size': 600}
# cuda_980ti
# avg_pool2d
# time
# ert
# 750
# {'device': 'cuda_980ti', 'workload': 'avg_pool2d', 'metric': 'time', 'predictor': 'ert', 'r2': 0.8146439830429566, 'max_error': 18.35317479999995, 'mae': 1.0050794290283884, 'mape': 0.8971689177359385, 'medae': 0.4315627874285701, 'dataset_min': 0.006952310000000001, 'dataset_max': 27.1845, 'dataset_mean': 3.2025548994400004, 'dataset_median': 1.45204, 'dataset_size': 750}
# cuda_980ti
# avg_pool2d
# time
# ert
# 900
# {'device': 'cuda_980ti', 'workload': 'avg_pool2d', 'metric': 'time', 'predictor': 'ert', 'r2': 0.8373286996049558, 'max_error': 18.217880171428533, 'mae': 0.9286134667723714, 'mape': 0.7492503744653396, 'medae': 0.4530996742857143, 'dataset_min': 0.006952310000000001, 'dataset_max': 27.1845, 'dataset_mean': 3.2124853026222224, 'dataset_median': 1.45204, 'dataset_size': 900}
# cuda_980ti
# avg_pool2d
# time
# ert
# 1050
# {'device': 'cuda_980ti', 'workload': 'avg_pool2d', 'metric': 'time', 'predictor': 'ert', 'r2': 0.8521269234869108, 'max_error': 18.411263085714314, 'mae': 0.8759737346179217, 'mape': 0.6657630693972614, 'medae': 0.4129343617142853, 'dataset_min': 0.006952310000000001, 'dataset_max': 37.962999999999994, 'dataset_mean': 3.3085905682476184, 'dataset_median': 1.45204, 'dataset_size': 1050}
# cuda_980ti
# avg_pool2d
# time
# ert
# 1200
# {'device': 'cuda_980ti', 'workload': 'avg_pool2d', 'metric': 'time', 'predictor': 'ert', 'r2': 0.8654991928508547, 'max_error': 18.017180302857096, 'mae': 0.8380094176098585, 'mape': 0.6318469819619434, 'medae': 0.38955060457142815, 'dataset_min': 0.006952310000000001, 'dataset_max': 37.962999999999994, 'dataset_mean': 3.3291847553500005, 'dataset_median': 1.45204, 'dataset_size': 1200}
# cuda_980ti
# avg_pool2d
# time
# ert
# 1350
# {'device': 'cuda_980ti', 'workload': 'avg_pool2d', 'metric': 'time', 'predictor': 'ert', 'r2': 0.8731121444146355, 'max_error': 16.682836400000017, 'mae': 0.8067526094404383, 'mape': 0.566030228637206, 'medae': 0.3758944080000002, 'dataset_min': 0.006952310000000001, 'dataset_max': 37.962999999999994, 'dataset_mean': 3.2708506505407406, 'dataset_median': 1.45204, 'dataset_size': 1350}
# cuda_980ti
# avg_pool2d
# time
# ert
# 1500
# {'device': 'cuda_980ti', 'workload': 'avg_pool2d', 'metric': 'time', 'predictor': 'ert', 'r2': 0.8800146458836525, 'max_error': 17.185508285714285, 'mae': 0.7823705957387493, 'mape': 0.54059990076726, 'medae': 0.3427152057142857, 'dataset_min': 0.006952310000000001, 'dataset_max': 37.962999999999994, 'dataset_mean': 3.301799913266667, 'dataset_median': 1.45204, 'dataset_size': 1500}
# cuda_980ti
# avg_pool2d
# time
# ert
# 1650
# {'device': 'cuda_980ti', 'workload': 'avg_pool2d', 'metric': 'time', 'predictor': 'ert', 'r2': 0.8865421789801986, 'max_error': 17.977927885714305, 'mae': 0.7429371703018407, 'mape': 0.4991580040025267, 'medae': 0.3269786400000001, 'dataset_min': 0.006952310000000001, 'dataset_max': 37.962999999999994, 'dataset_mean': 3.2749791628181817, 'dataset_median': 1.45204, 'dataset_size': 1650}
# cuda_980ti
# avg_pool2d
# time
# ert
# 1800
# {'device': 'cuda_980ti', 'workload': 'avg_pool2d', 'metric': 'time', 'predictor': 'ert', 'r2': 0.8859618171467335, 'max_error': 19.484261885714297, 'mae': 0.7499253765867028, 'mape': 0.5065173027251374, 'medae': 0.31990800057142865, 'dataset_min': 0.006952310000000001, 'dataset_max': 37.962999999999994, 'dataset_mean': 3.3135287985833335, 'dataset_median': 1.45204, 'dataset_size': 1800}
# cuda_980ti
# avg_pool2d
# time
# ert
# 1950
# {'device': 'cuda_980ti', 'workload': 'avg_pool2d', 'metric': 'time', 'predictor': 'ert', 'r2': 0.8893156245721124, 'max_error': 19.4060786857143, 'mae': 0.7298399430404381, 'mape': 0.4708873446211991, 'medae': 0.3323629714285774, 'dataset_min': 0.006952310000000001, 'dataset_max': 37.962999999999994, 'dataset_mean': 3.281242543307692, 'dataset_median': 1.45204, 'dataset_size': 1950}
# cuda_980ti
# avg_pool2d
# time
# ert
# 2100
# {'device': 'cuda_980ti', 'workload': 'avg_pool2d', 'metric': 'time', 'predictor': 'ert', 'r2': 0.8930926007693403, 'max_error': 20.437779257142875, 'mae': 0.7147107977282213, 'mape': 0.43250668965425354, 'medae': 0.27673130285714254, 'dataset_min': 0.006952310000000001, 'dataset_max': 37.962999999999994, 'dataset_mean': 3.289532160752381, 'dataset_median': 1.45204, 'dataset_size': 2100}
# cuda_980ti
# avg_pool2d
# time
# ert
# 2250
# {'device': 'cuda_980ti', 'workload': 'avg_pool2d', 'metric': 'time', 'predictor': 'ert', 'r2': 0.900143134091897, 'max_error': 20.884961314285725, 'mae': 0.6873503101399661, 'mape': 0.40286871559559156, 'medae': 0.24614585714285564, 'dataset_min': 0.006952310000000001, 'dataset_max': 37.962999999999994, 'dataset_mean': 3.2620990307377777, 'dataset_median': 1.45204, 'dataset_size': 2250}
# cuda_980ti
# avg_pool2d
# time
# ert
# 2400
# {'device': 'cuda_980ti', 'workload': 'avg_pool2d', 'metric': 'time', 'predictor': 'ert', 'r2': 0.9024182098214589, 'max_error': 19.964302342857152, 'mae': 0.6737041191967138, 'mape': 0.3905769766248915, 'medae': 0.28628869085714415, 'dataset_min': 0.006952310000000001, 'dataset_max': 37.962999999999994, 'dataset_mean': 3.2528571319333337, 'dataset_median': 1.45204, 'dataset_size': 2400}
# cuda_980ti
# avg_pool2d
# time
# ert
# 2550
# {'device': 'cuda_980ti', 'workload': 'avg_pool2d', 'metric': 'time', 'predictor': 'ert', 'r2': 0.9117977679924453, 'max_error': 21.48511611428573, 'mae': 0.6341868896909175, 'mape': 0.37254397259931665, 'medae': 0.25169645142857133, 'dataset_min': 0.006952310000000001, 'dataset_max': 37.962999999999994, 'dataset_mean': 3.258631113203921, 'dataset_median': 1.45204, 'dataset_size': 2550}
# cuda_980ti
# avg_pool2d
# time
# ert
# 2700
# {'device': 'cuda_980ti', 'workload': 'avg_pool2d', 'metric': 'time', 'predictor': 'ert', 'r2': 0.9141582030026576, 'max_error': 19.03885605714287, 'mae': 0.6189008536028601, 'mape': 0.35977457022699433, 'medae': 0.22926746285714328, 'dataset_min': 0.006952310000000001, 'dataset_max': 37.962999999999994, 'dataset_mean': 3.2745152525666668, 'dataset_median': 1.45204, 'dataset_size': 2700}
# cuda_980ti
# avg_pool2d
# time
# ert
# 2850

# %%
date_time = "size_investigation/results_rbst_scaler_980ti_"+str(int(time.time()))
results = pd.DataFrame.from_dict(results, "index")

# %%
results.to_csv(date_time+"-predictor_results.csv")
results.to_excel(date_time+"-predictor_results.xlsx")
results.to_html(date_time+"-predictor_results.html")
results.to_markdown(date_time+"-predictor_results.md")
print("done")

# %%
results

# %%
viz = results.set_index('dataset_size', inplace=False)
viz[(viz.metric == "time")  & (viz.workload == "conv2d")].groupby('predictor')["r2"].plot(kind="line", legend=True, figsize=(15,5))

#groupby('predictor').plot(legend=True)
